# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import sys

# %%
#Data Files
clean_data= '../First-Project/CleanDataset/clean_data.csv'

clean_data= pd.read_csv(clean_data)
clean_data.head()
# Out:
#    Unnamed: 0 Timestamp  FRUITS_VEGGIES  DAILY_STRESS  PLACES_VISITED  \
# 0           0  7/7/2015               3             2               2
# 1           1  7/7/2015               2             3               4
# 2           2  7/7/2015               2             3               3
# 3           3  7/7/2015               3             3              10
# 4           4  7/7/2015               5             1               3
#
#    CORE_CIRCLE  SUPPORTING_OTHERS  SOCIAL_NETWORK  ACHIEVEMENT  DONATION  ...  \
# 0            5                  0               5            2         0  ...
# 1            3                  8              10            5         2  ...
# 2            4                  4              10            3         2  ...
# 3            3                 10               7            2         5  ...
# 4            3                 10               4            2         4  ...
#
#    SLEEP_HOURS  LOST_VACATION  DAILY_SHOUTING  SUFFICIENT_INCOME  \
# ...

# %%
# Create a boxplot to compare means of the daily stress scores
boxstress= clean_data.boxplot('WORK_LIFE_BALANCE_SCORE', by="DAILY_STRESS", flierprops={'markerfacecolor':'r', 'markersize':10,'marker':'*'}, figsize=(20, 10))
plt.xlabel("Daily Stress Levels", fontweight= 'bold', fontsize= '20')
plt.xticks(fontweight='bold', fontsize='15')
plt.ylabel("Work Life Balance Score", fontweight= 'bold', fontsize= '20')
plt.yticks(fontweight='bold', fontsize='15')
plt.title("Daily Stress vs Work Life Balance Score", fontweight= 'bold', fontsize='20')
boxstress

plt.savefig('../First-Project/Output/tfig1.png',bbox_inches='tight')

# %%
ages= clean_data['AGE'].value_counts()
ages
# Out:
# 21 to 35        3486
# 36 to 50        2757
# 51 or more      2037
# Less than 20    1094
# Name: AGE, dtype: int64

# %%
#create a graph to show daily stress relative to age groups
age_groups= clean_data[['AGE', 'DAILY_STRESS']].sort_values('AGE')
age_groups
# Out:
#                AGE  DAILY_STRESS
# 9373      21 to 35             4
# 2939      21 to 35             3
# 2940      21 to 35             0
# 2941      21 to 35             1
# 2942      21 to 35             5
# ...            ...           ...
# 3976  Less than 20             1
# 5794  Less than 20             1
# 5795  Less than 20             2
# 924   Less than 20             4
# 7207  Less than 20             1
#
# [9374 rows x 2 columns]

# %%
#group the ages and count 'em 
group= age_groups.groupby(['AGE', 'DAILY_STRESS']).value_counts()
group
# Out:
# AGE           DAILY_STRESS
# 21 to 35      0               134
#               1               515
#               2               779
#               3               963
#               4               630
#               5               465
# 36 to 50      0                80
#               1               378
#               2               611
#               3               743
#               4               539
#               5               406
# 51 or more    0               132
#               1               399
#               2               418
#               3               508
#               4               353
#               5               227
# Less than 20  0                65
#               1               183
#               2               220
#               3               288
#               4               196
#               5               142
# dtype: int64

# %%
#group the ages
plt.figure(figsize=(15,4))
group= age_groups.groupby(['AGE','DAILY_STRESS']).value_counts().plot(kind='bar', align='center', width=.7, alpha=0.5)
group


plt.tight_layout
plt.title('Daily Stress Relative to Age Groups', fontweight='bold', fontsize='20')
plt.xlabel('Age Groups and Stress Levels', fontweight='bold')
plt.xticks(fontweight='bold')
plt.ylabel('Number of Stress Scores', fontweight='bold')
plt.yticks(fontweight='bold')

plt.savefig('../First-Project/Output/tfig2.png', bbox_inches='tight')
