# %%
import pandas as pd
import os
import csv
import matplotlib.pyplot as plt
import numpy as np

# %%
clean_df = pd.read_csv("CleanDataset\clean_data.csv")
clean_df.head()
# Out:
#              Timestamp  FRUITS_VEGGIES  DAILY_STRESS  PLACES_VISITED  \
# 0  2019-03-01 04:17:00               3             0              10
# 1  2019-03-02 22:26:00               2             3               7
# 2  2019-03-03 03:06:00               5             2               5
# 3  2019-03-03 12:20:00               1             5               6
# 4  2019-03-04 00:48:00               2             4              10
#
#    CORE_CIRCLE  SUPPORTING_OTHERS  SOCIAL_NETWORK  ACHIEVEMENT  DONATION  \
# 0           10                  9              10            7         3
# 1            7                  1               5            4         0
# 2            3                  4               3            4         0
# 3            5                 10               4            2         4
# 4            3                  3               1            1         4
#
#    BMI_RANGE  ...  SLEEP_HOURS  LOST_VACATION  DAILY_SHOUTING  \
# ...

# %%
minimized_df = clean_df[["BMI_RANGE", "SLEEP_HOURS", "AGE", "GENDER", "WORK_LIFE_BALANCE_SCORE"]].copy()
minimized_df.head()
# Out:
#    BMI_RANGE  SLEEP_HOURS           AGE  GENDER  WORK_LIFE_BALANCE_SCORE
# 0          2            8  Less than 20  Female                    699.1
# 1          2            7    51 or more  Female                    636.3
# 2          1            3      36 to 50  Female                    676.5
# 3          1            6      36 to 50  Female                    631.4
# 4          1            9      21 to 35  Female                    600.8

# %%
female_df = minimized_df[minimized_df['GENDER'] == 'Female']
male_df = minimized_df[minimized_df['GENDER'] == 'Male']
female_df.head()
# Out:
#    BMI_RANGE  SLEEP_HOURS           AGE  GENDER  WORK_LIFE_BALANCE_SCORE
# 0          2            8  Less than 20  Female                    699.1
# 1          2            7    51 or more  Female                    636.3
# 2          1            3      36 to 50  Female                    676.5
# 3          1            6      36 to 50  Female                    631.4
# 4          1            9      21 to 35  Female                    600.8

# %%
age_df = minimized_df[["AGE", "WORK_LIFE_BALANCE_SCORE"]]
age_df.head()
# Out:
#             AGE  WORK_LIFE_BALANCE_SCORE
# 0  Less than 20                    699.1
# 1    51 or more                    636.3
# 2      36 to 50                    676.5
# 3      36 to 50                    631.4
# 4      21 to 35                    600.8

# %%
x_axis = female_df["BMI_RANGE"]
y_axis = female_df["WORK_LIFE_BALANCE_SCORE"]

# %%
plt.plot(x_axis, y_axis)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
y_axis = male_df["BMI_RANGE"]
x_axis = male_df["WORK_LIFE_BALANCE_SCORE"]
plt.plot(x_axis, y_axis)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
